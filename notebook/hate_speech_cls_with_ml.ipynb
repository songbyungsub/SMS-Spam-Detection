# %%
import os
import re
import numpy as np
import pandas as pd

from os.path import join as pjoin

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier

from xgboost import XGBClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import f1_score
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
import joblib

def save_model(filename, model):
    if not filename.endswith(('.pkl', '.pickle')):
        filename += '.pickle'
    print(filename)
    joblib.dump(model, filename)

# %%
def is_nan(string):
    return string != string

# %% [markdown]
# ### **Data Load**

# %%
train = pd.read_csv('train.csv')[['proc_text', 'label']]
train = train.sample(frac=1)

valid = pd.read_csv('valid.csv')[['proc_text', 'label']]
valid = valid.sample(frac=1)

test = pd.read_csv('test.csv')[['proc_text', 'label']]
test = test.sample(frac=1)

len(train), len(valid), len(test)
# Out:
# (132999, 28498, 28498)

# %%
train = train.dropna(axis=0)

valid = valid.dropna(axis=0)

test = test.dropna(axis=0)
len(train), len(valid), len(test)
# Out:
# (132861, 28470, 28457)

# %%
dev = pd.concat([train, valid], ignore_index=True)

# %%
x_dev = dev['proc_text']
y_dev = dev['label']

# %%
x_train = train['proc_text']
y_train = train['label']

x_valid = valid['proc_text']
y_valid = valid['label']

x_test = test['proc_text']
y_test = test['label']

# %%
count_vect = CountVectorizer()
x_train_counts = count_vect.fit_transform(x_train)
x_valid_counts = count_vect.transform(x_valid)
x_test_counts = count_vect.transform(x_test)

x_train_counts.shape
# Out:
# (132861, 336627)

# %%
dev_cnt_vect = CountVectorizer()
x_dev_counts = dev_cnt_vect.fit_transform(x_dev)
x_dev_test_counts = dev_cnt_vect.transform(x_test)

dev_tfidf_transformer = TfidfTransformer()
x_dev_tfidf = dev_tfidf_transformer.fit_transform(x_dev_counts)
x_dev_test_tfidf = dev_tfidf_transformer.transform(x_dev_test_counts)

# %%
tfidf_transformer = TfidfTransformer()
x_train_tfidf = tfidf_transformer.fit_transform(x_train_counts)
x_valid_tfidf = tfidf_transformer.transform(x_valid_counts)
x_test_tfidf = tfidf_transformer.transform(x_test_counts)

x_train_tfidf.shape
# Out:
# (132861, 336627)

# %% [markdown]
# ### **Model Result**

# %%
result = pd.DataFrame(columns=['sentence', 'label', 'xgboost-pred', 'dt-pred', 'svc-pred'])
result['sentence'] = x_test
result['label'] = y_test

# %%
def test_model(model, input='ㅆ 너는 눈깔이 어디에 달렸냐'):
    if isinstance(model, XGBClassifier):
        print('XGBClassifier')
        input_test_counts = count_vect.transform([input])
        input_test_tfidf = tfidf_transformer.transform(input_test_counts)
    else:
        input_test_counts = dev_cnt_vect.transform([input])
        input_test_tfidf = dev_tfidf_transformer.transform(input_test_counts)
    pred = model.predict(input_test_tfidf)
    return pred

# %% [markdown]
# ### **XGBoost**

# %%
xgb_wrapper = XGBClassifier(n_estimators = 5000, 
                            learning_rate = 0.1 , 
                            max_depth = 8,
                            min_child_weight=1,
                            gamma=0,
                            subsample=0.8,
                            colsample_bytree=0.8,
                            objective= 'binary:logistic',
                            # num_class=2,
                            nthread=-1,
                            scale_pos_weight=1,
                            seed=42
                            )
evals = [(x_valid_tfidf, y_valid)]
xgb_wrapper.fit(x_train_tfidf, y_train, early_stopping_rounds = 100, 
                eval_set = evals, verbose=True)

ws100_preds = xgb_wrapper.predict(x_test_tfidf)
# Out:
# [0]	validation_0-error:0.388479
# Will train until validation_0-error hasn't improved in 100 rounds.
# [1]	validation_0-error:0.38163
# [2]	validation_0-error:0.375378
# [3]	validation_0-error:0.370706
# [4]	validation_0-error:0.370636
# [5]	validation_0-error:0.366175
# [6]	validation_0-error:0.359607
# [7]	validation_0-error:0.353214
# [8]	validation_0-error:0.353284
# [9]	validation_0-error:0.347208
# [10]	validation_0-error:0.347137
# [11]	validation_0-error:0.344924
# [12]	validation_0-error:0.339515
# [13]	validation_0-error:0.336319
# [14]	validation_0-error:0.334282
# [15]	validation_0-error:0.334317
# [16]	validation_0-error:0.331437
# [17]	validation_0-error:0.331366
# [18]	validation_0-error:0.331296
# [19]	validation_0-error:0.325641
# [20]	validation_0-error:0.325676
# [21]	validation_0-error:0.321848
# [22]	validation_0-error:0.321496
# [23]	validation_0-error:0.321461
# [24]	validation_0-error:0.319002
# [25]	validation_0-error:0.317316
# [26]	validation_0-error:0.317106
# [27]	validation_0-error:0.315841
# [28]	validation_0-error:0.311907
# [29]	validation_0-error:0.310889
# [30]	validation_0-error:0.307622
# [31]	validation_0-error:0.307692
# [32]	validation_0-error:0.306568
# [33]	validation_0-error:0.303056
# [34]	validation_0-error:0.3013
# [35]	validation_0-error:0.300141
# [36]	validation_0-error:0.3
# [37]	validation_0-error:0.299333
# [38]	validation_0-error:0.299192
# [39]	validation_0-error:0.299824
# [40]	validation_0-error:0.297436
# [41]	validation_0-error:0.295118
# [42]	validation_0-error:0.293678
# [43]	validation_0-error:0.291605
# [44]	validation_0-error:0.288795
# [45]	validation_0-error:0.287882
# [46]	validation_0-error:0.286653
# [47]	validation_0-error:0.284932
# [48]	validation_0-error:0.283913
# [49]	validation_0-error:0.283878
# [50]	validation_0-error:0.281595
# [51]	validation_0-error:0.281595
# [52]	validation_0-error:0.281454
# [53]	validation_0-error:0.280155
# [54]	validation_0-error:0.278539
# [55]	validation_0-error:0.276361
# [56]	validation_0-error:0.276291
# [57]	validation_0-error:0.275202
# [58]	validation_0-error:0.276115
# [59]	validation_0-error:0.275097
# [60]	validation_0-error:0.274886
# [61]	validation_0-error:0.274218
# [62]	validation_0-error:0.274113
# [63]	validation_0-error:0.274078
# [64]	validation_0-error:0.274078
# [65]	validation_0-error:0.273727
# [66]	validation_0-error:0.273727
# [67]	validation_0-error:0.272708
# [68]	validation_0-error:0.27197
# [69]	validation_0-error:0.270882
# [70]	validation_0-error:0.270706
# [71]	validation_0-error:0.270671
# [72]	validation_0-error:0.269968
# [73]	validation_0-error:0.269863
# [74]	validation_0-error:0.26902
# [75]	validation_0-error:0.269161
# [76]	validation_0-error:0.269933
# [77]	validation_0-error:0.267229
# [78]	validation_0-error:0.266386
# [79]	validation_0-error:0.265648
# [80]	validation_0-error:0.266526
# [81]	validation_0-error:0.265929
# [82]	validation_0-error:0.264946
# [83]	validation_0-error:0.26477
# [84]	validation_0-error:0.263646
# [85]	validation_0-error:0.263611
# [86]	validation_0-error:0.262136
# [87]	validation_0-error:0.261644
# [88]	validation_0-error:0.261609
# [89]	validation_0-error:0.259817
# [90]	validation_0-error:0.259361
# [91]	validation_0-error:0.259185
# [92]	validation_0-error:0.259115
# [93]	validation_0-error:0.257464
# [94]	validation_0-error:0.25641
# [95]	validation_0-error:0.2562
# [96]	validation_0-error:0.256164
# [97]	validation_0-error:0.255567
# [98]	validation_0-error:0.255146
# [99]	validation_0-error:0.25497
# [100]	validation_0-error:0.255321
# [101]	validation_0-error:0.253846
# [102]	validation_0-error:0.253495
# [103]	validation_0-error:0.252582
# [104]	validation_0-error:0.252371
# [105]	validation_0-error:0.252511
# [106]	validation_0-error:0.25216
# [107]	validation_0-error:0.251106
# [108]	validation_0-error:0.251106
# [109]	validation_0-error:0.251317
# [110]	validation_0-error:0.251879
# [111]	validation_0-error:0.251949
# [112]	validation_0-error:0.251036
# [113]	validation_0-error:0.250263
# [114]	validation_0-error:0.24935
# [115]	validation_0-error:0.249245
# [116]	validation_0-error:0.249561
# [117]	validation_0-error:0.249175
# [118]	validation_0-error:0.248542
# [119]	validation_0-error:0.248683
# [120]	validation_0-error:0.248823
# [121]	validation_0-error:0.249034
# [122]	validation_0-error:0.247805
# [123]	validation_0-error:0.247875
# [124]	validation_0-error:0.247629
# [125]	validation_0-error:0.247524
# [126]	validation_0-error:0.246856
# [127]	validation_0-error:0.246435
# [128]	validation_0-error:0.2451
# [129]	validation_0-error:0.244889
# [130]	validation_0-error:0.245135
# [131]	validation_0-error:0.245767
# [132]	validation_0-error:0.245486
# [133]	validation_0-error:0.245416
# [134]	validation_0-error:0.244538
# [135]	validation_0-error:0.244573
# [136]	validation_0-error:0.244257
# [137]	validation_0-error:0.243414
# [138]	validation_0-error:0.242536
# [139]	validation_0-error:0.242466
# [140]	validation_0-error:0.242501
# [141]	validation_0-error:0.24071
# [142]	validation_0-error:0.240007
# [143]	validation_0-error:0.239867
# [144]	validation_0-error:0.239761
# [145]	validation_0-error:0.23941
# [146]	validation_0-error:0.239129
# [147]	validation_0-error:0.239024
# [148]	validation_0-error:0.239024
# [149]	validation_0-error:0.238953
# [150]	validation_0-error:0.238321
# [151]	validation_0-error:0.238145
# [152]	validation_0-error:0.237794
# [153]	validation_0-error:0.23797
# [154]	validation_0-error:0.2379
# [155]	validation_0-error:0.237864
# [156]	validation_0-error:0.237829
# [157]	validation_0-error:0.237443
# [158]	validation_0-error:0.236916
# [159]	validation_0-error:0.236635
# [160]	validation_0-error:0.236495
# [161]	validation_0-error:0.236038
# [162]	validation_0-error:0.235968
# [163]	validation_0-error:0.235897
# [164]	validation_0-error:0.235441
# [165]	validation_0-error:0.235406
# [166]	validation_0-error:0.235265
# [167]	validation_0-error:0.235125
# [168]	validation_0-error:0.235054
# [169]	validation_0-error:0.23509
# [170]	validation_0-error:0.234949
# [171]	validation_0-error:0.234528
# [172]	validation_0-error:0.234071
# [173]	validation_0-error:0.233966
# [174]	validation_0-error:0.233895
# [175]	validation_0-error:0.233509
# [176]	validation_0-error:0.233017
# [177]	validation_0-error:0.233017
# [178]	validation_0-error:0.232771
# [179]	validation_0-error:0.232631
# [180]	validation_0-error:0.232139
# [181]	validation_0-error:0.232104
# [182]	validation_0-error:0.231788
# [183]	validation_0-error:0.231542
# [184]	validation_0-error:0.23105
# [185]	validation_0-error:0.230804
# [186]	validation_0-error:0.230207
# [187]	validation_0-error:0.230102
# [188]	validation_0-error:0.229996
# [189]	validation_0-error:0.229715
# [190]	validation_0-error:0.229259
# [191]	validation_0-error:0.228486
# [192]	validation_0-error:0.228135
# [193]	validation_0-error:0.2281
# [194]	validation_0-error:0.227819
# [195]	validation_0-error:0.227819
# [196]	validation_0-error:0.227749
# [197]	validation_0-error:0.227151
# [198]	validation_0-error:0.227011
# [199]	validation_0-error:0.226625
# [200]	validation_0-error:0.226273
# [201]	validation_0-error:0.226027
# [202]	validation_0-error:0.225782
# [203]	validation_0-error:0.225746
# [204]	validation_0-error:0.225606
# [205]	validation_0-error:0.225571
# [206]	validation_0-error:0.225501
# [207]	validation_0-error:0.22522
# [208]	validation_0-error:0.224939
# [209]	validation_0-error:0.224868
# [210]	validation_0-error:0.224341
# [211]	validation_0-error:0.223674
# [212]	validation_0-error:0.223604
# [213]	validation_0-error:0.223604
# [214]	validation_0-error:0.223463
# [215]	validation_0-error:0.223042
# [216]	validation_0-error:0.223112
# [217]	validation_0-error:0.223147
# [218]	validation_0-error:0.222831
# [219]	validation_0-error:0.222655
# [220]	validation_0-error:0.22248
# [221]	validation_0-error:0.221812
# [222]	validation_0-error:0.221356
# [223]	validation_0-error:0.220864
# [224]	validation_0-error:0.220372
# [225]	validation_0-error:0.220162
# [226]	validation_0-error:0.2196
# [227]	validation_0-error:0.219002
# [228]	validation_0-error:0.219073
# [229]	validation_0-error:0.218721
# [230]	validation_0-error:0.218686
# [231]	validation_0-error:0.218546
# [232]	validation_0-error:0.21844
# [233]	validation_0-error:0.218335
# [234]	validation_0-error:0.217984
# [235]	validation_0-error:0.217597
# [236]	validation_0-error:0.217211
# [237]	validation_0-error:0.217176
# [238]	validation_0-error:0.217071
# [239]	validation_0-error:0.21679
# [240]	validation_0-error:0.216684
# [241]	validation_0-error:0.216649
# [242]	validation_0-error:0.216579
# [243]	validation_0-error:0.216438
# [244]	validation_0-error:0.216122
# [245]	validation_0-error:0.21556
# [246]	validation_0-error:0.215385
# [247]	validation_0-error:0.215244
# [248]	validation_0-error:0.215244
# [249]	validation_0-error:0.215104
# [250]	validation_0-error:0.214893
# [251]	validation_0-error:0.214647
# [252]	validation_0-error:0.214577
# [253]	validation_0-error:0.214471
# [254]	validation_0-error:0.214155
# [255]	validation_0-error:0.214155
# [256]	validation_0-error:0.213909
# [257]	validation_0-error:0.213804
# [258]	validation_0-error:0.213804
# [259]	validation_0-error:0.213804
# [260]	validation_0-error:0.213664
# [261]	validation_0-error:0.213699
# [262]	validation_0-error:0.213558
# [263]	validation_0-error:0.213488
# [264]	validation_0-error:0.213312
# [265]	validation_0-error:0.212856
# [266]	validation_0-error:0.21275
# [267]	validation_0-error:0.212715
# [268]	validation_0-error:0.21254
# [269]	validation_0-error:0.212399
# [270]	validation_0-error:0.212259
# [271]	validation_0-error:0.211837
# [272]	validation_0-error:0.211802
# [273]	validation_0-error:0.211802
# [274]	validation_0-error:0.211767
# [275]	validation_0-error:0.211345
# [276]	validation_0-error:0.211205
# [277]	validation_0-error:0.210994
# [278]	validation_0-error:0.210854
# [279]	validation_0-error:0.210643
# [280]	validation_0-error:0.210573
# [281]	validation_0-error:0.210467
# [282]	validation_0-error:0.210432
# [283]	validation_0-error:0.210432
# [284]	validation_0-error:0.210151
# [285]	validation_0-error:0.210081
# [286]	validation_0-error:0.209975
# [287]	validation_0-error:0.209694
# [288]	validation_0-error:0.209132
# [289]	validation_0-error:0.208922
# [290]	validation_0-error:0.208781
# [291]	validation_0-error:0.208746
# [292]	validation_0-error:0.208711
# [293]	validation_0-error:0.208641
# [294]	validation_0-error:0.208149
# [295]	validation_0-error:0.208114
# [296]	validation_0-error:0.207763
# [297]	validation_0-error:0.207622
# [298]	validation_0-error:0.207657
# [299]	validation_0-error:0.207763
# [300]	validation_0-error:0.207622
# [301]	validation_0-error:0.207727
# [302]	validation_0-error:0.207587
# [303]	validation_0-error:0.207306
# [304]	validation_0-error:0.207201
# [305]	validation_0-error:0.20699
# [306]	validation_0-error:0.206955
# [307]	validation_0-error:0.206533
# [308]	validation_0-error:0.206252
# [309]	validation_0-error:0.205901
# [310]	validation_0-error:0.205831
# [311]	validation_0-error:0.205831
# [312]	validation_0-error:0.205831
# [313]	validation_0-error:0.205796
# [314]	validation_0-error:0.205444
# [315]	validation_0-error:0.205269
# [316]	validation_0-error:0.205163
# [317]	validation_0-error:0.205198
# [318]	validation_0-error:0.204917
# [319]	validation_0-error:0.204882
# [320]	validation_0-error:0.204777
# [321]	validation_0-error:0.204742
# [322]	validation_0-error:0.204601
# [323]	validation_0-error:0.204636
# [324]	validation_0-error:0.204566
# [325]	validation_0-error:0.204496
# [326]	validation_0-error:0.204531
# [327]	validation_0-error:0.20425
# [328]	validation_0-error:0.20425
# [329]	validation_0-error:0.204004
# [330]	validation_0-error:0.204074
# [331]	validation_0-error:0.203899
# [332]	validation_0-error:0.203793
# [333]	validation_0-error:0.203512
# [334]	validation_0-error:0.203477
# [335]	validation_0-error:0.203337
# [336]	validation_0-error:0.203196
# [337]	validation_0-error:0.203091
# [338]	validation_0-error:0.202845
# [339]	validation_0-error:0.202564
# [340]	validation_0-error:0.202529
# [341]	validation_0-error:0.202248
# [342]	validation_0-error:0.202143
# [343]	validation_0-error:0.201791
# [344]	validation_0-error:0.201932
# [345]	validation_0-error:0.201826
# [346]	validation_0-error:0.201791
# [347]	validation_0-error:0.201791
# [348]	validation_0-error:0.201475
# [349]	validation_0-error:0.201616
# [350]	validation_0-error:0.201616
# [351]	validation_0-error:0.201545
# [352]	validation_0-error:0.201335
# [353]	validation_0-error:0.201124
# [354]	validation_0-error:0.201089
# [355]	validation_0-error:0.201229
# [356]	validation_0-error:0.2013
# [357]	validation_0-error:0.2013
# [358]	validation_0-error:0.200843
# [359]	validation_0-error:0.200562
# [360]	validation_0-error:0.200316
# [361]	validation_0-error:0.200316
# [362]	validation_0-error:0.200281
# [363]	validation_0-error:0.200246
# [364]	validation_0-error:0.200246
# [365]	validation_0-error:0.200035
# [366]	validation_0-error:0.19993
# [367]	validation_0-error:0.19993
# [368]	validation_0-error:0.19993
# [369]	validation_0-error:0.199754
# [370]	validation_0-error:0.199473
# [371]	validation_0-error:0.199403
# [372]	validation_0-error:0.199227
# [373]	validation_0-error:0.199192
# [374]	validation_0-error:0.199227
# [375]	validation_0-error:0.199227
# [376]	validation_0-error:0.199192
# [377]	validation_0-error:0.199192
# [378]	validation_0-error:0.199122
# [379]	validation_0-error:0.198981
# [380]	validation_0-error:0.198946
# [381]	validation_0-error:0.198946
# [382]	validation_0-error:0.198911
# [383]	validation_0-error:0.198876
# [384]	validation_0-error:0.198806
# [385]	validation_0-error:0.1987
# [386]	validation_0-error:0.198736
# [387]	validation_0-error:0.19849
# [388]	validation_0-error:0.198103
# [389]	validation_0-error:0.197857
# [390]	validation_0-error:0.197717
# [391]	validation_0-error:0.197682
# [392]	validation_0-error:0.197612
# [393]	validation_0-error:0.197682
# [394]	validation_0-error:0.197647
# [395]	validation_0-error:0.197612
# [396]	validation_0-error:0.197541
# [397]	validation_0-error:0.197401
# [398]	validation_0-error:0.197401
# [399]	validation_0-error:0.197085
# [400]	validation_0-error:0.197085
# [401]	validation_0-error:0.19712
# [402]	validation_0-error:0.197014
# [403]	validation_0-error:0.197014
# [404]	validation_0-error:0.197014
# [405]	validation_0-error:0.196909
# [406]	validation_0-error:0.196909
# [407]	validation_0-error:0.196909
# [408]	validation_0-error:0.196874
# [409]	validation_0-error:0.196874
# [410]	validation_0-error:0.196804
# [411]	validation_0-error:0.196769
# [412]	validation_0-error:0.196733
# [413]	validation_0-error:0.196663
# [414]	validation_0-error:0.196663
# [415]	validation_0-error:0.196663
# [416]	validation_0-error:0.196558
# [417]	validation_0-error:0.196593
# [418]	validation_0-error:0.196417
# [419]	validation_0-error:0.196277
# [420]	validation_0-error:0.196207
# [421]	validation_0-error:0.196101
# [422]	validation_0-error:0.196031
# [423]	validation_0-error:0.195926
# [424]	validation_0-error:0.19568
# [425]	validation_0-error:0.195574
# [426]	validation_0-error:0.195609
# [427]	validation_0-error:0.195785
# [428]	validation_0-error:0.195715
# [429]	validation_0-error:0.195645
# [430]	validation_0-error:0.19575
# [431]	validation_0-error:0.19568
# [432]	validation_0-error:0.195469
# [433]	validation_0-error:0.195118
# [434]	validation_0-error:0.195012
# [435]	validation_0-error:0.195047
# [436]	validation_0-error:0.195012
# [437]	validation_0-error:0.194977
# [438]	validation_0-error:0.194837
# [439]	validation_0-error:0.194766
# [440]	validation_0-error:0.194626
# [441]	validation_0-error:0.194485
# [442]	validation_0-error:0.19431
# [443]	validation_0-error:0.194275
# [444]	validation_0-error:0.19424
# [445]	validation_0-error:0.19424
# [446]	validation_0-error:0.194204
# [447]	validation_0-error:0.194169
# [448]	validation_0-error:0.194064
# [449]	validation_0-error:0.194134
# [450]	validation_0-error:0.193853
# [451]	validation_0-error:0.193607
# [452]	validation_0-error:0.193397
# [453]	validation_0-error:0.193397
# [454]	validation_0-error:0.193291
# [455]	validation_0-error:0.192694
# [456]	validation_0-error:0.192694
# [457]	validation_0-error:0.192694
# [458]	validation_0-error:0.192659
# [459]	validation_0-error:0.192483
# [460]	validation_0-error:0.192413
# [461]	validation_0-error:0.192413
# [462]	validation_0-error:0.192237
# [463]	validation_0-error:0.192132
# [464]	validation_0-error:0.192132
# [465]	validation_0-error:0.192062
# [466]	validation_0-error:0.192097
# [467]	validation_0-error:0.192062
# [468]	validation_0-error:0.191956
# [469]	validation_0-error:0.191816
# [470]	validation_0-error:0.191921
# [471]	validation_0-error:0.191851
# [472]	validation_0-error:0.191711
# [473]	validation_0-error:0.191781
# [474]	validation_0-error:0.191781
# [475]	validation_0-error:0.191781
# [476]	validation_0-error:0.19164
# [477]	validation_0-error:0.19143
# [478]	validation_0-error:0.19164
# [479]	validation_0-error:0.191605
# [480]	validation_0-error:0.19143
# [481]	validation_0-error:0.191394
# [482]	validation_0-error:0.191394
# [483]	validation_0-error:0.191289
# [484]	validation_0-error:0.190938
# [485]	validation_0-error:0.190903
# [486]	validation_0-error:0.190938
# [487]	validation_0-error:0.190868
# [488]	validation_0-error:0.190832
# [489]	validation_0-error:0.190762
# [490]	validation_0-error:0.190903
# [491]	validation_0-error:0.190727
# [492]	validation_0-error:0.190622
# [493]	validation_0-error:0.190306
# [494]	validation_0-error:0.190446
# [495]	validation_0-error:0.190411
# [496]	validation_0-error:0.190411
# [497]	validation_0-error:0.190376
# [498]	validation_0-error:0.190341
# [499]	validation_0-error:0.190306
# [500]	validation_0-error:0.190165
# [501]	validation_0-error:0.190165
# [502]	validation_0-error:0.1902
# [503]	validation_0-error:0.19027
# [504]	validation_0-error:0.190235
# [505]	validation_0-error:0.190235
# [506]	validation_0-error:0.19013
# [507]	validation_0-error:0.19006
# [508]	validation_0-error:0.190025
# [509]	validation_0-error:0.19013
# [510]	validation_0-error:0.19013
# [511]	validation_0-error:0.189989
# [512]	validation_0-error:0.189919
# [513]	validation_0-error:0.189849
# [514]	validation_0-error:0.189849
# [515]	validation_0-error:0.189814
# [516]	validation_0-error:0.189708
# [517]	validation_0-error:0.189673
# [518]	validation_0-error:0.189427
# [519]	validation_0-error:0.189392
# [520]	validation_0-error:0.189427
# [521]	validation_0-error:0.189357
# [522]	validation_0-error:0.189392
# [523]	validation_0-error:0.189287
# [524]	validation_0-error:0.189252
# [525]	validation_0-error:0.189217
# [526]	validation_0-error:0.189006
# [527]	validation_0-error:0.188936
# [528]	validation_0-error:0.188865
# [529]	validation_0-error:0.188865
# [530]	validation_0-error:0.188795
# [531]	validation_0-error:0.188795
# [532]	validation_0-error:0.188795
# [533]	validation_0-error:0.188795
# [534]	validation_0-error:0.188936
# [535]	validation_0-error:0.188725
# [536]	validation_0-error:0.18869
# [537]	validation_0-error:0.188655
# [538]	validation_0-error:0.188549
# [539]	validation_0-error:0.188479
# [540]	validation_0-error:0.188374
# [541]	validation_0-error:0.188374
# [542]	validation_0-error:0.188268
# [543]	validation_0-error:0.187987
# [544]	validation_0-error:0.187987
# [545]	validation_0-error:0.187812
# [546]	validation_0-error:0.187777
# [547]	validation_0-error:0.188093
# [548]	validation_0-error:0.188022
# [549]	validation_0-error:0.187882
# [550]	validation_0-error:0.18746
# [551]	validation_0-error:0.18732
# [552]	validation_0-error:0.18725
# [553]	validation_0-error:0.187004
# [554]	validation_0-error:0.187109
# [555]	validation_0-error:0.187039
# [556]	validation_0-error:0.186934
# [557]	validation_0-error:0.186723
# [558]	validation_0-error:0.186582
# [559]	validation_0-error:0.186442
# [560]	validation_0-error:0.186407
# [561]	validation_0-error:0.186301
# [562]	validation_0-error:0.186231
# [563]	validation_0-error:0.186231
# [564]	validation_0-error:0.186126
# [565]	validation_0-error:0.185985
# [566]	validation_0-error:0.185985
# [567]	validation_0-error:0.18595
# [568]	validation_0-error:0.18595
# [569]	validation_0-error:0.18595
# [570]	validation_0-error:0.185564
# [571]	validation_0-error:0.185458
# [572]	validation_0-error:0.185458
# [573]	validation_0-error:0.185388
# [574]	validation_0-error:0.185318
# [575]	validation_0-error:0.185353
# [576]	validation_0-error:0.185388
# [577]	validation_0-error:0.185318
# [578]	validation_0-error:0.185037
# [579]	validation_0-error:0.185142
# [580]	validation_0-error:0.185002
# [581]	validation_0-error:0.185037
# [582]	validation_0-error:0.185072
# [583]	validation_0-error:0.185107
# [584]	validation_0-error:0.185248
# [585]	validation_0-error:0.185142
# [586]	validation_0-error:0.185388
# [587]	validation_0-error:0.185423
# [588]	validation_0-error:0.185423
# [589]	validation_0-error:0.185213
# [590]	validation_0-error:0.185177
# [591]	validation_0-error:0.185423
# [592]	validation_0-error:0.185213
# [593]	validation_0-error:0.185248
# [594]	validation_0-error:0.185107
# [595]	validation_0-error:0.185107
# [596]	validation_0-error:0.184896
# [597]	validation_0-error:0.184721
# [598]	validation_0-error:0.184791
# [599]	validation_0-error:0.184791
# [600]	validation_0-error:0.184791
# [601]	validation_0-error:0.184791
# [602]	validation_0-error:0.184791
# [603]	validation_0-error:0.184756
# [604]	validation_0-error:0.184721
# [605]	validation_0-error:0.184615
# [606]	validation_0-error:0.184545
# [607]	validation_0-error:0.184405
# [608]	validation_0-error:0.184299
# [609]	validation_0-error:0.184264
# [610]	validation_0-error:0.184229
# [611]	validation_0-error:0.184194
# [612]	validation_0-error:0.184159
# [613]	validation_0-error:0.184159
# [614]	validation_0-error:0.184124
# [615]	validation_0-error:0.183843
# [616]	validation_0-error:0.183808
# [617]	validation_0-error:0.183527
# [618]	validation_0-error:0.183386
# [619]	validation_0-error:0.183421
# [620]	validation_0-error:0.183421
# [621]	validation_0-error:0.183386
# [622]	validation_0-error:0.183386
# [623]	validation_0-error:0.183316
# [624]	validation_0-error:0.183316
# [625]	validation_0-error:0.183175
# [626]	validation_0-error:0.183175
# [627]	validation_0-error:0.18314
# [628]	validation_0-error:0.18314
# [629]	validation_0-error:0.183246
# [630]	validation_0-error:0.18321
# [631]	validation_0-error:0.183246
# [632]	validation_0-error:0.183175
# [633]	validation_0-error:0.182965
# [634]	validation_0-error:0.182929
# [635]	validation_0-error:0.182929
# [636]	validation_0-error:0.182824
# [637]	validation_0-error:0.182824
# [638]	validation_0-error:0.182789
# [639]	validation_0-error:0.182965
# [640]	validation_0-error:0.182929
# [641]	validation_0-error:0.182859
# [642]	validation_0-error:0.182929
# [643]	validation_0-error:0.183105
# [644]	validation_0-error:0.183
# [645]	validation_0-error:0.182965
# [646]	validation_0-error:0.18307
# [647]	validation_0-error:0.182965
# [648]	validation_0-error:0.183
# [649]	validation_0-error:0.182859
# [650]	validation_0-error:0.182754
# [651]	validation_0-error:0.182859
# [652]	validation_0-error:0.182789
# [653]	validation_0-error:0.182754
# [654]	validation_0-error:0.182648
# [655]	validation_0-error:0.182508
# [656]	validation_0-error:0.182192
# [657]	validation_0-error:0.182157
# [658]	validation_0-error:0.182157
# [659]	validation_0-error:0.182157
# [660]	validation_0-error:0.182367
# [661]	validation_0-error:0.182332
# [662]	validation_0-error:0.182332
# [663]	validation_0-error:0.182051
# [664]	validation_0-error:0.182297
# [665]	validation_0-error:0.182262
# [666]	validation_0-error:0.182227
# [667]	validation_0-error:0.182192
# [668]	validation_0-error:0.182051
# [669]	validation_0-error:0.182051
# [670]	validation_0-error:0.182016
# [671]	validation_0-error:0.181946
# [672]	validation_0-error:0.181911
# [673]	validation_0-error:0.181805
# [674]	validation_0-error:0.181805
# [675]	validation_0-error:0.181805
# [676]	validation_0-error:0.181805
# [677]	validation_0-error:0.18177
# [678]	validation_0-error:0.1817
# [679]	validation_0-error:0.181735
# [680]	validation_0-error:0.181665
# [681]	validation_0-error:0.1817
# [682]	validation_0-error:0.18177
# [683]	validation_0-error:0.181595
# [684]	validation_0-error:0.181384
# [685]	validation_0-error:0.181384
# [686]	validation_0-error:0.181349
# [687]	validation_0-error:0.181419
# [688]	validation_0-error:0.181349
# [689]	validation_0-error:0.181419
# [690]	validation_0-error:0.181349
# [691]	validation_0-error:0.181384
# [692]	validation_0-error:0.181314
# [693]	validation_0-error:0.181243
# [694]	validation_0-error:0.181454
# [695]	validation_0-error:0.181489
# [696]	validation_0-error:0.181454
# [697]	validation_0-error:0.181314
# [698]	validation_0-error:0.181138
# [699]	validation_0-error:0.181103
# [700]	validation_0-error:0.181033
# [701]	validation_0-error:0.180927
# [702]	validation_0-error:0.180822
# [703]	validation_0-error:0.180787
# [704]	validation_0-error:0.180717
# [705]	validation_0-error:0.180787
# [706]	validation_0-error:0.180927
# [707]	validation_0-error:0.180752
# [708]	validation_0-error:0.180611
# [709]	validation_0-error:0.180717
# [710]	validation_0-error:0.180576
# [711]	validation_0-error:0.180506
# [712]	validation_0-error:0.180506
# [713]	validation_0-error:0.180471
# [714]	validation_0-error:0.180155
# [715]	validation_0-error:0.180119
# [716]	validation_0-error:0.179979
# [717]	validation_0-error:0.179909
# [718]	validation_0-error:0.179979
# [719]	validation_0-error:0.180049
# [720]	validation_0-error:0.180014
# [721]	validation_0-error:0.179838
# [722]	validation_0-error:0.179768
# [723]	validation_0-error:0.179838
# [724]	validation_0-error:0.179909
# [725]	validation_0-error:0.179944
# [726]	validation_0-error:0.179979
# [727]	validation_0-error:0.179979
# [728]	validation_0-error:0.179909
# [729]	validation_0-error:0.179768
# [730]	validation_0-error:0.179803
# [731]	validation_0-error:0.179768
# [732]	validation_0-error:0.179593
# [733]	validation_0-error:0.179628
# [734]	validation_0-error:0.179628
# [735]	validation_0-error:0.179593
# [736]	validation_0-error:0.179487
# [737]	validation_0-error:0.179382
# [738]	validation_0-error:0.179382
# [739]	validation_0-error:0.179347
# [740]	validation_0-error:0.179066
# [741]	validation_0-error:0.179031
# [742]	validation_0-error:0.178995
# [743]	validation_0-error:0.178995
# [744]	validation_0-error:0.178995
# [745]	validation_0-error:0.178995
# [746]	validation_0-error:0.17889
# [747]	validation_0-error:0.17882
# [748]	validation_0-error:0.17875
# [749]	validation_0-error:0.178714
# [750]	validation_0-error:0.178714
# [751]	validation_0-error:0.178679
# [752]	validation_0-error:0.178433
# [753]	validation_0-error:0.178363
# [754]	validation_0-error:0.178363
# [755]	validation_0-error:0.178433
# [756]	validation_0-error:0.178117
# [757]	validation_0-error:0.178082
# [758]	validation_0-error:0.178047
# [759]	validation_0-error:0.178012
# [760]	validation_0-error:0.178082
# [761]	validation_0-error:0.178117
# [762]	validation_0-error:0.178047
# [763]	validation_0-error:0.178047
# [764]	validation_0-error:0.178012
# [765]	validation_0-error:0.178082
# [766]	validation_0-error:0.178082
# [767]	validation_0-error:0.178012
# [768]	validation_0-error:0.177836
# [769]	validation_0-error:0.177801
# [770]	validation_0-error:0.177766
# [771]	validation_0-error:0.177661
# [772]	validation_0-error:0.177696
# [773]	validation_0-error:0.177555
# [774]	validation_0-error:0.17745
# [775]	validation_0-error:0.17745
# [776]	validation_0-error:0.17752
# [777]	validation_0-error:0.177555
# [778]	validation_0-error:0.17752
# [779]	validation_0-error:0.17752
# [780]	validation_0-error:0.17745
# [781]	validation_0-error:0.177309
# [782]	validation_0-error:0.177309
# [783]	validation_0-error:0.177239
# [784]	validation_0-error:0.177204
# [785]	validation_0-error:0.177204
# [786]	validation_0-error:0.177169
# [787]	validation_0-error:0.177204
# [788]	validation_0-error:0.177134
# [789]	validation_0-error:0.177099
# [790]	validation_0-error:0.177099
# [791]	validation_0-error:0.176783
# [792]	validation_0-error:0.176853
# [793]	validation_0-error:0.176923
# [794]	validation_0-error:0.176923
# [795]	validation_0-error:0.176783
# [796]	validation_0-error:0.176783
# [797]	validation_0-error:0.176783
# [798]	validation_0-error:0.176783
# [799]	validation_0-error:0.176677
# [800]	validation_0-error:0.176642
# [801]	validation_0-error:0.176677
# [802]	validation_0-error:0.176642
# [803]	validation_0-error:0.176502
# [804]	validation_0-error:0.176466
# [805]	validation_0-error:0.176537
# [806]	validation_0-error:0.176572
# [807]	validation_0-error:0.176572
# [808]	validation_0-error:0.176537
# [809]	validation_0-error:0.176502
# [810]	validation_0-error:0.176396
# [811]	validation_0-error:0.176431
# [812]	validation_0-error:0.176396
# [813]	validation_0-error:0.176326
# [814]	validation_0-error:0.176185
# [815]	validation_0-error:0.176185
# [816]	validation_0-error:0.176045
# [817]	validation_0-error:0.17594
# [818]	validation_0-error:0.17594
# [819]	validation_0-error:0.175869
# [820]	validation_0-error:0.175869
# [821]	validation_0-error:0.175904
# [822]	validation_0-error:0.175799
# [823]	validation_0-error:0.175659
# [824]	validation_0-error:0.175623
# [825]	validation_0-error:0.175799
# [826]	validation_0-error:0.175623
# [827]	validation_0-error:0.175729
# [828]	validation_0-error:0.175588
# [829]	validation_0-error:0.175694
# [830]	validation_0-error:0.175483
# [831]	validation_0-error:0.175448
# [832]	validation_0-error:0.175483
# [833]	validation_0-error:0.175448
# [834]	validation_0-error:0.175342
# [835]	validation_0-error:0.175132
# [836]	validation_0-error:0.175132
# [837]	validation_0-error:0.175167
# [838]	validation_0-error:0.175132
# [839]	validation_0-error:0.175167
# [840]	validation_0-error:0.175167
# [841]	validation_0-error:0.175061
# [842]	validation_0-error:0.175097
# [843]	validation_0-error:0.175061
# [844]	validation_0-error:0.174956
# [845]	validation_0-error:0.174956
# [846]	validation_0-error:0.174921
# [847]	validation_0-error:0.174956
# [848]	validation_0-error:0.174956
# [849]	validation_0-error:0.174956
# [850]	validation_0-error:0.174921
# [851]	validation_0-error:0.17478
# [852]	validation_0-error:0.174605
# [853]	validation_0-error:0.174605
# [854]	validation_0-error:0.174499
# [855]	validation_0-error:0.174289
# [856]	validation_0-error:0.174218
# [857]	validation_0-error:0.174183
# [858]	validation_0-error:0.174148
# [859]	validation_0-error:0.174183
# [860]	validation_0-error:0.174008
# [861]	validation_0-error:0.174008
# [862]	validation_0-error:0.173797
# [863]	validation_0-error:0.173797
# [864]	validation_0-error:0.173867
# [865]	validation_0-error:0.173867
# [866]	validation_0-error:0.173832
# [867]	validation_0-error:0.173762
# [868]	validation_0-error:0.173727
# [869]	validation_0-error:0.173832
# [870]	validation_0-error:0.173832
# [871]	validation_0-error:0.173867
# [872]	validation_0-error:0.173902
# [873]	validation_0-error:0.173867
# [874]	validation_0-error:0.173832
# [875]	validation_0-error:0.173832
# [876]	validation_0-error:0.173797
# [877]	validation_0-error:0.173692
# [878]	validation_0-error:0.173656
# [879]	validation_0-error:0.173516
# [880]	validation_0-error:0.173586
# [881]	validation_0-error:0.173692
# [882]	validation_0-error:0.173656
# [883]	validation_0-error:0.173586
# [884]	validation_0-error:0.173586
# [885]	validation_0-error:0.173621
# [886]	validation_0-error:0.173481
# [887]	validation_0-error:0.173375
# [888]	validation_0-error:0.173305
# [889]	validation_0-error:0.173305
# [890]	validation_0-error:0.17334
# [891]	validation_0-error:0.173235
# [892]	validation_0-error:0.173235
# [893]	validation_0-error:0.17327
# [894]	validation_0-error:0.173305
# [895]	validation_0-error:0.173165
# [896]	validation_0-error:0.17313
# [897]	validation_0-error:0.173305
# [898]	validation_0-error:0.1732
# [899]	validation_0-error:0.173305
# [900]	validation_0-error:0.17313
# [901]	validation_0-error:0.173024
# [902]	validation_0-error:0.173059
# [903]	validation_0-error:0.172989
# [904]	validation_0-error:0.172954
# [905]	validation_0-error:0.172919
# [906]	validation_0-error:0.172849
# [907]	validation_0-error:0.172884
# [908]	validation_0-error:0.172884
# [909]	validation_0-error:0.172673
# [910]	validation_0-error:0.172849
# [911]	validation_0-error:0.172813
# [912]	validation_0-error:0.172813
# [913]	validation_0-error:0.172603
# [914]	validation_0-error:0.172638
# [915]	validation_0-error:0.172568
# [916]	validation_0-error:0.172603
# [917]	validation_0-error:0.172462
# [918]	validation_0-error:0.172427
# [919]	validation_0-error:0.172322
# [920]	validation_0-error:0.172322
# [921]	validation_0-error:0.172322
# [922]	validation_0-error:0.172251
# [923]	validation_0-error:0.172251
# [924]	validation_0-error:0.172041
# [925]	validation_0-error:0.172041
# [926]	validation_0-error:0.172041
# [927]	validation_0-error:0.172216
# [928]	validation_0-error:0.172216
# [929]	validation_0-error:0.172216
# [930]	validation_0-error:0.172251
# [931]	validation_0-error:0.172251
# [932]	validation_0-error:0.172041
# [933]	validation_0-error:0.172076
# [934]	validation_0-error:0.172216
# [935]	validation_0-error:0.172216
# [936]	validation_0-error:0.172146
# [937]	validation_0-error:0.171971
# [938]	validation_0-error:0.171971
# [939]	validation_0-error:0.1719
# [940]	validation_0-error:0.171865
# [941]	validation_0-error:0.171971
# [942]	validation_0-error:0.171971
# [943]	validation_0-error:0.171935
# [944]	validation_0-error:0.171795
# [945]	validation_0-error:0.171689
# [946]	validation_0-error:0.171654
# [947]	validation_0-error:0.171689
# [948]	validation_0-error:0.171654
# [949]	validation_0-error:0.171584
# [950]	validation_0-error:0.171479
# [951]	validation_0-error:0.171549
# [952]	validation_0-error:0.171479
# [953]	validation_0-error:0.171444
# [954]	validation_0-error:0.171373
# [955]	validation_0-error:0.171409
# [956]	validation_0-error:0.171373
# [957]	validation_0-error:0.171444
# [958]	validation_0-error:0.171198
# [959]	validation_0-error:0.171092
# [960]	validation_0-error:0.171092
# [961]	validation_0-error:0.171092
# [962]	validation_0-error:0.171338
# [963]	validation_0-error:0.171303
# [964]	validation_0-error:0.171268
# [965]	validation_0-error:0.171268
# [966]	validation_0-error:0.171233
# [967]	validation_0-error:0.171198
# [968]	validation_0-error:0.171022
# [969]	validation_0-error:0.170987
# [970]	validation_0-error:0.170882
# [971]	validation_0-error:0.170847
# [972]	validation_0-error:0.170882
# [973]	validation_0-error:0.170882
# [974]	validation_0-error:0.170882
# [975]	validation_0-error:0.170847
# [976]	validation_0-error:0.170847
# [977]	validation_0-error:0.170776
# [978]	validation_0-error:0.170741
# [979]	validation_0-error:0.170776
# [980]	validation_0-error:0.170776
# [981]	validation_0-error:0.170847
# [982]	validation_0-error:0.170882
# [983]	validation_0-error:0.170847
# [984]	validation_0-error:0.170811
# [985]	validation_0-error:0.170776
# [986]	validation_0-error:0.170776
# [987]	validation_0-error:0.170741
# [988]	validation_0-error:0.170741
# [989]	validation_0-error:0.170706
# [990]	validation_0-error:0.170671
# [991]	validation_0-error:0.170671
# [992]	validation_0-error:0.170495
# [993]	validation_0-error:0.17039
# [994]	validation_0-error:0.17039
# [995]	validation_0-error:0.17032
# [996]	validation_0-error:0.170355
# [997]	validation_0-error:0.170355
# [998]	validation_0-error:0.170355
# [999]	validation_0-error:0.17032
# [1000]	validation_0-error:0.170179
# [1001]	validation_0-error:0.170109
# [1002]	validation_0-error:0.170039
# [1003]	validation_0-error:0.170074
# [1004]	validation_0-error:0.170004
# [1005]	validation_0-error:0.170004
# [1006]	validation_0-error:0.170074
# [1007]	validation_0-error:0.170039
# [1008]	validation_0-error:0.170004
# [1009]	validation_0-error:0.169933
# [1010]	validation_0-error:0.170004
# [1011]	validation_0-error:0.169968
# [1012]	validation_0-error:0.169863
# [1013]	validation_0-error:0.169793
# [1014]	validation_0-error:0.169793
# [1015]	validation_0-error:0.169793
# [1016]	validation_0-error:0.169793
# [1017]	validation_0-error:0.169793
# [1018]	validation_0-error:0.170039
# [1019]	validation_0-error:0.170039
# [1020]	validation_0-error:0.170144
# [1021]	validation_0-error:0.170249
# [1022]	validation_0-error:0.170285
# [1023]	validation_0-error:0.170179
# [1024]	validation_0-error:0.170144
# [1025]	validation_0-error:0.170144
# [1026]	validation_0-error:0.170039
# [1027]	validation_0-error:0.170109
# [1028]	validation_0-error:0.170144
# [1029]	validation_0-error:0.169933
# [1030]	validation_0-error:0.169898
# [1031]	validation_0-error:0.169723
# [1032]	validation_0-error:0.169793
# [1033]	validation_0-error:0.169652
# [1034]	validation_0-error:0.169582
# [1035]	validation_0-error:0.169547
# [1036]	validation_0-error:0.169512
# [1037]	validation_0-error:0.169512
# [1038]	validation_0-error:0.169617
# [1039]	validation_0-error:0.169617
# [1040]	validation_0-error:0.169512
# [1041]	validation_0-error:0.169512
# [1042]	validation_0-error:0.169652
# [1043]	validation_0-error:0.169652
# [1044]	validation_0-error:0.169652
# [1045]	validation_0-error:0.169687
# [1046]	validation_0-error:0.169652
# [1047]	validation_0-error:0.169687
# [1048]	validation_0-error:0.169687
# [1049]	validation_0-error:0.169582
# [1050]	validation_0-error:0.169512
# [1051]	validation_0-error:0.169442
# [1052]	validation_0-error:0.169442
# [1053]	validation_0-error:0.169442
# [1054]	validation_0-error:0.169442
# [1055]	validation_0-error:0.169406
# [1056]	validation_0-error:0.169406
# [1057]	validation_0-error:0.169371
# [1058]	validation_0-error:0.169336
# [1059]	validation_0-error:0.169336
# [1060]	validation_0-error:0.169266
# [1061]	validation_0-error:0.169231
# [1062]	validation_0-error:0.16909
# [1063]	validation_0-error:0.169125
# [1064]	validation_0-error:0.169125
# [1065]	validation_0-error:0.169125
# [1066]	validation_0-error:0.169055
# [1067]	validation_0-error:0.169055
# [1068]	validation_0-error:0.16909
# [1069]	validation_0-error:0.16902
# [1070]	validation_0-error:0.169196
# [1071]	validation_0-error:0.16909
# [1072]	validation_0-error:0.169266
# [1073]	validation_0-error:0.169231
# [1074]	validation_0-error:0.169196
# [1075]	validation_0-error:0.169161
# [1076]	validation_0-error:0.169196
# [1077]	validation_0-error:0.168915
# [1078]	validation_0-error:0.16888
# [1079]	validation_0-error:0.168985
# [1080]	validation_0-error:0.16888
# [1081]	validation_0-error:0.168844
# [1082]	validation_0-error:0.168915
# [1083]	validation_0-error:0.168915
# [1084]	validation_0-error:0.16888
# [1085]	validation_0-error:0.168774
# [1086]	validation_0-error:0.168809
# [1087]	validation_0-error:0.168809
# [1088]	validation_0-error:0.168809
# [1089]	validation_0-error:0.16888
# [1090]	validation_0-error:0.168844
# [1091]	validation_0-error:0.168774
# [1092]	validation_0-error:0.168669
# [1093]	validation_0-error:0.168599
# [1094]	validation_0-error:0.168528
# [1095]	validation_0-error:0.168528
# [1096]	validation_0-error:0.168528
# [1097]	validation_0-error:0.168458
# [1098]	validation_0-error:0.168458
# [1099]	validation_0-error:0.168458
# [1100]	validation_0-error:0.168458
# [1101]	validation_0-error:0.168458
# [1102]	validation_0-error:0.168493
# [1103]	validation_0-error:0.168458
# [1104]	validation_0-error:0.168388
# [1105]	validation_0-error:0.168388
# [1106]	validation_0-error:0.168353
# [1107]	validation_0-error:0.168388
# [1108]	validation_0-error:0.168282
# [1109]	validation_0-error:0.168212
# [1110]	validation_0-error:0.168177
# [1111]	validation_0-error:0.168107
# [1112]	validation_0-error:0.168072
# [1113]	validation_0-error:0.168037
# [1114]	validation_0-error:0.168107
# [1115]	validation_0-error:0.168037
# [1116]	validation_0-error:0.168037
# [1117]	validation_0-error:0.168037
# [1118]	validation_0-error:0.168037
# [1119]	validation_0-error:0.168001
# [1120]	validation_0-error:0.167861
# [1121]	validation_0-error:0.167861
# [1122]	validation_0-error:0.167826
# [1123]	validation_0-error:0.167826
# [1124]	validation_0-error:0.16772
# [1125]	validation_0-error:0.16772
# [1126]	validation_0-error:0.16772
# [1127]	validation_0-error:0.167685
# [1128]	validation_0-error:0.16765
# [1129]	validation_0-error:0.16751
# [1130]	validation_0-error:0.16751
# [1131]	validation_0-error:0.16751
# [1132]	validation_0-error:0.16751
# [1133]	validation_0-error:0.167475
# [1134]	validation_0-error:0.167475
# [1135]	validation_0-error:0.167369
# [1136]	validation_0-error:0.167369
# [1137]	validation_0-error:0.167369
# [1138]	validation_0-error:0.167369
# [1139]	validation_0-error:0.167404
# [1140]	validation_0-error:0.167439
# [1141]	validation_0-error:0.167475
# [1142]	validation_0-error:0.167475
# [1143]	validation_0-error:0.167369
# [1144]	validation_0-error:0.167334
# [1145]	validation_0-error:0.167229
# [1146]	validation_0-error:0.167229
# [1147]	validation_0-error:0.167229
# [1148]	validation_0-error:0.167229
# [1149]	validation_0-error:0.167229
# [1150]	validation_0-error:0.167264
# [1151]	validation_0-error:0.167264
# [1152]	validation_0-error:0.167299
# [1153]	validation_0-error:0.167194
# [1154]	validation_0-error:0.167158
# [1155]	validation_0-error:0.167088
# [1156]	validation_0-error:0.166983
# [1157]	validation_0-error:0.166983
# [1158]	validation_0-error:0.166948
# [1159]	validation_0-error:0.166877
# [1160]	validation_0-error:0.166877
# [1161]	validation_0-error:0.166877
# [1162]	validation_0-error:0.166842
# [1163]	validation_0-error:0.166842
# [1164]	validation_0-error:0.166807
# [1165]	validation_0-error:0.166737
# [1166]	validation_0-error:0.166737
# [1167]	validation_0-error:0.166632
# [1168]	validation_0-error:0.166596
# [1169]	validation_0-error:0.166421
# [1170]	validation_0-error:0.166456
# [1171]	validation_0-error:0.166421
# [1172]	validation_0-error:0.166421
# [1173]	validation_0-error:0.166351
# [1174]	validation_0-error:0.166245
# [1175]	validation_0-error:0.166245
# [1176]	validation_0-error:0.16621
# [1177]	validation_0-error:0.16621
# [1178]	validation_0-error:0.16621
# [1179]	validation_0-error:0.166175
# [1180]	validation_0-error:0.16628
# [1181]	validation_0-error:0.16614
# [1182]	validation_0-error:0.16614
# [1183]	validation_0-error:0.16614
# [1184]	validation_0-error:0.16614
# [1185]	validation_0-error:0.16614
# [1186]	validation_0-error:0.16614
# [1187]	validation_0-error:0.166105
# [1188]	validation_0-error:0.16614
# [1189]	validation_0-error:0.16621
# [1190]	validation_0-error:0.166245
# [1191]	validation_0-error:0.166245
# [1192]	validation_0-error:0.16628
# [1193]	validation_0-error:0.16621
# [1194]	validation_0-error:0.166175
# [1195]	validation_0-error:0.16614
# [1196]	validation_0-error:0.166034
# [1197]	validation_0-error:0.165999
# [1198]	validation_0-error:0.165999
# [1199]	validation_0-error:0.165929
# [1200]	validation_0-error:0.165964
# [1201]	validation_0-error:0.165964
# [1202]	validation_0-error:0.165964
# [1203]	validation_0-error:0.165964
# [1204]	validation_0-error:0.165929
# [1205]	validation_0-error:0.165964
# [1206]	validation_0-error:0.165964
# [1207]	validation_0-error:0.165929
# [1208]	validation_0-error:0.165929
# [1209]	validation_0-error:0.165894
# [1210]	validation_0-error:0.165859
# [1211]	validation_0-error:0.165824
# [1212]	validation_0-error:0.165718
# [1213]	validation_0-error:0.165718
# [1214]	validation_0-error:0.165718
# [1215]	validation_0-error:0.165824
# [1216]	validation_0-error:0.165789
# [1217]	validation_0-error:0.165753
# [1218]	validation_0-error:0.165789
# [1219]	validation_0-error:0.165753
# [1220]	validation_0-error:0.165753
# [1221]	validation_0-error:0.165683
# [1222]	validation_0-error:0.165683
# [1223]	validation_0-error:0.165648
# [1224]	validation_0-error:0.165648
# [1225]	validation_0-error:0.165718
# [1226]	validation_0-error:0.165683
# [1227]	validation_0-error:0.165683
# [1228]	validation_0-error:0.165718
# [1229]	validation_0-error:0.165789
# [1230]	validation_0-error:0.165789
# [1231]	validation_0-error:0.165648
# [1232]	validation_0-error:0.165683
# [1233]	validation_0-error:0.165613
# [1234]	validation_0-error:0.165578
# [1235]	validation_0-error:0.165578
# [1236]	validation_0-error:0.165543
# [1237]	validation_0-error:0.165543
# [1238]	validation_0-error:0.165543
# [1239]	validation_0-error:0.165508
# [1240]	validation_0-error:0.165472
# [1241]	validation_0-error:0.165437
# [1242]	validation_0-error:0.165437
# [1243]	validation_0-error:0.165402
# [1244]	validation_0-error:0.165402
# [1245]	validation_0-error:0.165402
# [1246]	validation_0-error:0.165367
# [1247]	validation_0-error:0.165367
# [1248]	validation_0-error:0.165367
# [1249]	validation_0-error:0.165367
# [1250]	validation_0-error:0.165402
# [1251]	validation_0-error:0.165437
# [1252]	validation_0-error:0.165367
# [1253]	validation_0-error:0.165367
# [1254]	validation_0-error:0.165332
# [1255]	validation_0-error:0.165332
# [1256]	validation_0-error:0.165332
# [1257]	validation_0-error:0.165332
# [1258]	validation_0-error:0.165227
# [1259]	validation_0-error:0.165191
# [1260]	validation_0-error:0.165156
# [1261]	validation_0-error:0.165121
# [1262]	validation_0-error:0.165156
# [1263]	validation_0-error:0.165156
# [1264]	validation_0-error:0.165051
# [1265]	validation_0-error:0.165121
# [1266]	validation_0-error:0.165051
# [1267]	validation_0-error:0.165051
# [1268]	validation_0-error:0.165051
# [1269]	validation_0-error:0.16491
# [1270]	validation_0-error:0.16491
# [1271]	validation_0-error:0.16491
# [1272]	validation_0-error:0.16491
# [1273]	validation_0-error:0.16491
# [1274]	validation_0-error:0.16491
# [1275]	validation_0-error:0.16491
# [1276]	validation_0-error:0.164981
# [1277]	validation_0-error:0.164981
# [1278]	validation_0-error:0.16491
# [1279]	validation_0-error:0.164875
# [1280]	validation_0-error:0.16484
# [1281]	validation_0-error:0.164875
# [1282]	validation_0-error:0.16491
# [1283]	validation_0-error:0.16491
# [1284]	validation_0-error:0.16484
# [1285]	validation_0-error:0.16484
# [1286]	validation_0-error:0.16477
# [1287]	validation_0-error:0.164735
# [1288]	validation_0-error:0.164489
# [1289]	validation_0-error:0.164454
# [1290]	validation_0-error:0.164454
# [1291]	validation_0-error:0.164384
# [1292]	validation_0-error:0.164384
# [1293]	validation_0-error:0.164348
# [1294]	validation_0-error:0.164384
# [1295]	validation_0-error:0.164348
# [1296]	validation_0-error:0.164384
# [1297]	validation_0-error:0.164419
# [1298]	validation_0-error:0.164454
# [1299]	validation_0-error:0.164348
# [1300]	validation_0-error:0.164278
# [1301]	validation_0-error:0.164278
# [1302]	validation_0-error:0.164243
# [1303]	validation_0-error:0.164173
# [1304]	validation_0-error:0.164208
# [1305]	validation_0-error:0.164173
# [1306]	validation_0-error:0.164173
# [1307]	validation_0-error:0.164138
# [1308]	validation_0-error:0.163997
# [1309]	validation_0-error:0.163997
# [1310]	validation_0-error:0.163997
# [1311]	validation_0-error:0.163997
# [1312]	validation_0-error:0.163927
# [1313]	validation_0-error:0.163927
# [1314]	validation_0-error:0.163997
# [1315]	validation_0-error:0.164032
# [1316]	validation_0-error:0.164032
# [1317]	validation_0-error:0.164032
# [1318]	validation_0-error:0.163962
# [1319]	validation_0-error:0.163927
# [1320]	validation_0-error:0.163892
# [1321]	validation_0-error:0.163822
# [1322]	validation_0-error:0.163786
# [1323]	validation_0-error:0.163857
# [1324]	validation_0-error:0.164067
# [1325]	validation_0-error:0.164103
# [1326]	validation_0-error:0.164032
# [1327]	validation_0-error:0.164067
# [1328]	validation_0-error:0.164032
# [1329]	validation_0-error:0.163962
# [1330]	validation_0-error:0.164032
# [1331]	validation_0-error:0.164032
# [1332]	validation_0-error:0.163997
# [1333]	validation_0-error:0.164032
# [1334]	validation_0-error:0.163997
# [1335]	validation_0-error:0.163962
# [1336]	validation_0-error:0.163962
# [1337]	validation_0-error:0.163927
# [1338]	validation_0-error:0.163927
# [1339]	validation_0-error:0.163892
# [1340]	validation_0-error:0.163962
# [1341]	validation_0-error:0.163927
# [1342]	validation_0-error:0.163927
# [1343]	validation_0-error:0.163892
# [1344]	validation_0-error:0.163927
# [1345]	validation_0-error:0.163892
# [1346]	validation_0-error:0.163786
# [1347]	validation_0-error:0.163786
# [1348]	validation_0-error:0.163646
# [1349]	validation_0-error:0.163646
# [1350]	validation_0-error:0.163541
# [1351]	validation_0-error:0.163365
# [1352]	validation_0-error:0.16333
# [1353]	validation_0-error:0.163365
# [1354]	validation_0-error:0.163295
# [1355]	validation_0-error:0.163224
# [1356]	validation_0-error:0.163189
# [1357]	validation_0-error:0.163154
# [1358]	validation_0-error:0.163224
# [1359]	validation_0-error:0.163189
# [1360]	validation_0-error:0.163119
# [1361]	validation_0-error:0.163084
# [1362]	validation_0-error:0.163049
# [1363]	validation_0-error:0.163049
# [1364]	validation_0-error:0.162979
# [1365]	validation_0-error:0.162979
# [1366]	validation_0-error:0.162908
# [1367]	validation_0-error:0.162873
# [1368]	validation_0-error:0.162838
# [1369]	validation_0-error:0.162838
# [1370]	validation_0-error:0.162838
# [1371]	validation_0-error:0.162803
# [1372]	validation_0-error:0.162768
# [1373]	validation_0-error:0.162803
# [1374]	validation_0-error:0.162803
# [1375]	validation_0-error:0.162803
# [1376]	validation_0-error:0.162768
# [1377]	validation_0-error:0.162768
# [1378]	validation_0-error:0.162733
# [1379]	validation_0-error:0.162768
# [1380]	validation_0-error:0.162768
# [1381]	validation_0-error:0.162768
# [1382]	validation_0-error:0.162768
# [1383]	validation_0-error:0.162733
# [1384]	validation_0-error:0.162733
# [1385]	validation_0-error:0.162698
# [1386]	validation_0-error:0.162698
# [1387]	validation_0-error:0.162698
# [1388]	validation_0-error:0.162803
# [1389]	validation_0-error:0.162803
# [1390]	validation_0-error:0.162803
# [1391]	validation_0-error:0.162838
# [1392]	validation_0-error:0.162803
# [1393]	validation_0-error:0.162803
# [1394]	validation_0-error:0.162803
# [1395]	validation_0-error:0.162838
# [1396]	validation_0-error:0.162838
# [1397]	validation_0-error:0.162803
# [1398]	validation_0-error:0.162768
# [1399]	validation_0-error:0.162873
# [1400]	validation_0-error:0.162908
# [1401]	validation_0-error:0.162873
# [1402]	validation_0-error:0.162838
# [1403]	validation_0-error:0.162838
# [1404]	validation_0-error:0.162698
# ...
# [2921]	validation_0-error:0.150615
# [2922]	validation_0-error:0.150615
# [2923]	validation_0-error:0.150615
# [2924]	validation_0-error:0.150685
# [2925]	validation_0-error:0.150685
# [2926]	validation_0-error:0.150685
# [2927]	validation_0-error:0.150685
# [2928]	validation_0-error:0.15065
# [2929]	validation_0-error:0.15058
# [2930]	validation_0-error:0.150544
# [2931]	validation_0-error:0.15058
# [2932]	validation_0-error:0.15058
# [2933]	validation_0-error:0.150615
# [2934]	validation_0-error:0.150615
# [2935]	validation_0-error:0.150615
# [2936]	validation_0-error:0.15058
# [2937]	validation_0-error:0.150615
# [2938]	validation_0-error:0.15065
# [2939]	validation_0-error:0.150615
# [2940]	validation_0-error:0.15058
# [2941]	validation_0-error:0.15058
# [2942]	validation_0-error:0.150509
# [2943]	validation_0-error:0.150509
# [2944]	validation_0-error:0.150544
# [2945]	validation_0-error:0.150544
# [2946]	validation_0-error:0.150509
# [2947]	validation_0-error:0.15058
# [2948]	validation_0-error:0.15058
# [2949]	validation_0-error:0.15058
# [2950]	validation_0-error:0.150544
# [2951]	validation_0-error:0.150544
# [2952]	validation_0-error:0.150509
# [2953]	validation_0-error:0.15058
# [2954]	validation_0-error:0.150544
# [2955]	validation_0-error:0.150509
# [2956]	validation_0-error:0.150509
# [2957]	validation_0-error:0.15058
# [2958]	validation_0-error:0.15058
# [2959]	validation_0-error:0.15058
# [2960]	validation_0-error:0.150615
# [2961]	validation_0-error:0.150615
# [2962]	validation_0-error:0.150544
# [2963]	validation_0-error:0.150544
# [2964]	validation_0-error:0.150544
# [2965]	validation_0-error:0.150615
# [2966]	validation_0-error:0.15058
# [2967]	validation_0-error:0.15065
# [2968]	validation_0-error:0.150685
# [2969]	validation_0-error:0.15072
# [2970]	validation_0-error:0.150755
# [2971]	validation_0-error:0.150755
# [2972]	validation_0-error:0.150755
# [2973]	validation_0-error:0.150755
# [2974]	validation_0-error:0.150755
# [2975]	validation_0-error:0.15079
# [2976]	validation_0-error:0.15072
# [2977]	validation_0-error:0.15072
# [2978]	validation_0-error:0.15072
# [2979]	validation_0-error:0.15072
# [2980]	validation_0-error:0.15072
# [2981]	validation_0-error:0.15065
# [2982]	validation_0-error:0.150615
# [2983]	validation_0-error:0.150615
# [2984]	validation_0-error:0.15058
# [2985]	validation_0-error:0.150544
# [2986]	validation_0-error:0.150544
# [2987]	validation_0-error:0.150544
# [2988]	validation_0-error:0.150544
# [2989]	validation_0-error:0.150544
# [2990]	validation_0-error:0.150544
# [2991]	validation_0-error:0.15058
# [2992]	validation_0-error:0.150544
# [2993]	validation_0-error:0.150544
# [2994]	validation_0-error:0.150544
# [2995]	validation_0-error:0.150544
# [2996]	validation_0-error:0.150615
# [2997]	validation_0-error:0.150544
# [2998]	validation_0-error:0.150474
# [2999]	validation_0-error:0.150474
# [3000]	validation_0-error:0.150544
# [3001]	validation_0-error:0.150474
# [3002]	validation_0-error:0.150474
# [3003]	validation_0-error:0.150474
# [3004]	validation_0-error:0.150509
# [3005]	validation_0-error:0.150509
# [3006]	validation_0-error:0.150509
# [3007]	validation_0-error:0.150474
# [3008]	validation_0-error:0.150439
# [3009]	validation_0-error:0.150404
# [3010]	validation_0-error:0.150369
# [3011]	validation_0-error:0.150369
# [3012]	validation_0-error:0.150369
# [3013]	validation_0-error:0.150369
# [3014]	validation_0-error:0.150299
# [3015]	validation_0-error:0.150299
# [3016]	validation_0-error:0.150299
# [3017]	validation_0-error:0.150299
# [3018]	validation_0-error:0.150228
# [3019]	validation_0-error:0.150228
# [3020]	validation_0-error:0.150228
# [3021]	validation_0-error:0.150263
# [3022]	validation_0-error:0.150263
# [3023]	validation_0-error:0.150334
# [3024]	validation_0-error:0.150334
# [3025]	validation_0-error:0.150334
# [3026]	validation_0-error:0.150299
# [3027]	validation_0-error:0.150299
# [3028]	validation_0-error:0.150299
# [3029]	validation_0-error:0.150299
# [3030]	validation_0-error:0.150299
# [3031]	validation_0-error:0.150404
# [3032]	validation_0-error:0.150369
# [3033]	validation_0-error:0.150369
# [3034]	validation_0-error:0.150369
# [3035]	validation_0-error:0.150369
# [3036]	validation_0-error:0.150369
# [3037]	validation_0-error:0.150404
# [3038]	validation_0-error:0.150439
# [3039]	validation_0-error:0.150439
# [3040]	validation_0-error:0.150474
# [3041]	validation_0-error:0.150474
# [3042]	validation_0-error:0.150474
# [3043]	validation_0-error:0.150474
# [3044]	validation_0-error:0.150439
# [3045]	validation_0-error:0.150369
# [3046]	validation_0-error:0.150369
# [3047]	validation_0-error:0.150369
# [3048]	validation_0-error:0.150334
# [3049]	validation_0-error:0.150263
# [3050]	validation_0-error:0.150334
# [3051]	validation_0-error:0.150299
# [3052]	validation_0-error:0.150263
# [3053]	validation_0-error:0.150334
# [3054]	validation_0-error:0.150334
# [3055]	validation_0-error:0.150334
# [3056]	validation_0-error:0.150369
# [3057]	validation_0-error:0.150299
# [3058]	validation_0-error:0.150299
# [3059]	validation_0-error:0.150334
# [3060]	validation_0-error:0.150334
# [3061]	validation_0-error:0.150228
# [3062]	validation_0-error:0.150228
# [3063]	validation_0-error:0.150263
# [3064]	validation_0-error:0.150299
# [3065]	validation_0-error:0.150228
# [3066]	validation_0-error:0.150263
# [3067]	validation_0-error:0.150228
# [3068]	validation_0-error:0.150299
# [3069]	validation_0-error:0.150334
# [3070]	validation_0-error:0.150228
# [3071]	validation_0-error:0.150228
# [3072]	validation_0-error:0.150158
# [3073]	validation_0-error:0.150193
# [3074]	validation_0-error:0.150228
# [3075]	validation_0-error:0.150193
# [3076]	validation_0-error:0.150193
# [3077]	validation_0-error:0.150193
# [3078]	validation_0-error:0.150193
# [3079]	validation_0-error:0.150123
# [3080]	validation_0-error:0.150193
# [3081]	validation_0-error:0.150158
# [3082]	validation_0-error:0.150123
# [3083]	validation_0-error:0.150088
# [3084]	validation_0-error:0.150088
# [3085]	validation_0-error:0.150088
# [3086]	validation_0-error:0.150123
# [3087]	validation_0-error:0.150123
# [3088]	validation_0-error:0.150123
# [3089]	validation_0-error:0.150018
# [3090]	validation_0-error:0.150053
# [3091]	validation_0-error:0.150053
# [3092]	validation_0-error:0.149947
# [3093]	validation_0-error:0.149982
# [3094]	validation_0-error:0.150088
# [3095]	validation_0-error:0.150018
# [3096]	validation_0-error:0.150018
# [3097]	validation_0-error:0.150018
# [3098]	validation_0-error:0.150018
# [3099]	validation_0-error:0.150018
# [3100]	validation_0-error:0.149982
# [3101]	validation_0-error:0.149982
# [3102]	validation_0-error:0.150053
# [3103]	validation_0-error:0.150053
# [3104]	validation_0-error:0.150053
# [3105]	validation_0-error:0.150088
# [3106]	validation_0-error:0.150088
# [3107]	validation_0-error:0.150088
# [3108]	validation_0-error:0.150088
# [3109]	validation_0-error:0.150053
# [3110]	validation_0-error:0.150018
# [3111]	validation_0-error:0.150018
# [3112]	validation_0-error:0.149982
# [3113]	validation_0-error:0.149982
# [3114]	validation_0-error:0.149947
# [3115]	validation_0-error:0.149947
# [3116]	validation_0-error:0.149947
# [3117]	validation_0-error:0.149947
# [3118]	validation_0-error:0.149947
# [3119]	validation_0-error:0.149947
# [3120]	validation_0-error:0.149947
# [3121]	validation_0-error:0.149947
# [3122]	validation_0-error:0.149947
# [3123]	validation_0-error:0.149877
# [3124]	validation_0-error:0.149912
# [3125]	validation_0-error:0.149912
# [3126]	validation_0-error:0.149912
# [3127]	validation_0-error:0.149772
# [3128]	validation_0-error:0.149842
# [3129]	validation_0-error:0.149842
# [3130]	validation_0-error:0.149807
# [3131]	validation_0-error:0.149737
# [3132]	validation_0-error:0.149737
# [3133]	validation_0-error:0.149701
# [3134]	validation_0-error:0.149737
# [3135]	validation_0-error:0.149737
# [3136]	validation_0-error:0.149737
# [3137]	validation_0-error:0.149737
# [3138]	validation_0-error:0.149737
# [3139]	validation_0-error:0.149737
# [3140]	validation_0-error:0.149737
# [3141]	validation_0-error:0.149666
# [3142]	validation_0-error:0.149772
# [3143]	validation_0-error:0.149666
# [3144]	validation_0-error:0.149631
# [3145]	validation_0-error:0.149596
# [3146]	validation_0-error:0.149631
# [3147]	validation_0-error:0.149596
# [3148]	validation_0-error:0.149596
# [3149]	validation_0-error:0.149561
# [3150]	validation_0-error:0.149596
# [3151]	validation_0-error:0.149701
# [3152]	validation_0-error:0.149701
# [3153]	validation_0-error:0.149561
# [3154]	validation_0-error:0.149596
# [3155]	validation_0-error:0.149596
# [3156]	validation_0-error:0.149666
# [3157]	validation_0-error:0.149737
# [3158]	validation_0-error:0.149737
# [3159]	validation_0-error:0.149631
# [3160]	validation_0-error:0.149666
# [3161]	validation_0-error:0.149596
# [3162]	validation_0-error:0.149631
# [3163]	validation_0-error:0.149526
# [3164]	validation_0-error:0.149491
# [3165]	validation_0-error:0.149526
# [3166]	validation_0-error:0.149596
# [3167]	validation_0-error:0.149526
# [3168]	validation_0-error:0.149491
# [3169]	validation_0-error:0.149456
# [3170]	validation_0-error:0.149526
# [3171]	validation_0-error:0.149456
# [3172]	validation_0-error:0.14942
# [3173]	validation_0-error:0.14942
# [3174]	validation_0-error:0.149456
# [3175]	validation_0-error:0.149456
# [3176]	validation_0-error:0.149491
# [3177]	validation_0-error:0.149491
# [3178]	validation_0-error:0.149526
# [3179]	validation_0-error:0.149491
# [3180]	validation_0-error:0.149456
# [3181]	validation_0-error:0.149456
# [3182]	validation_0-error:0.149456
# [3183]	validation_0-error:0.149491
# [3184]	validation_0-error:0.149491
# [3185]	validation_0-error:0.149491
# [3186]	validation_0-error:0.149561
# [3187]	validation_0-error:0.149456
# [3188]	validation_0-error:0.14942
# [3189]	validation_0-error:0.149456
# [3190]	validation_0-error:0.149526
# [3191]	validation_0-error:0.149561
# [3192]	validation_0-error:0.149596
# [3193]	validation_0-error:0.149561
# [3194]	validation_0-error:0.149561
# [3195]	validation_0-error:0.149561
# [3196]	validation_0-error:0.149561
# [3197]	validation_0-error:0.14935
# [3198]	validation_0-error:0.149385
# [3199]	validation_0-error:0.149315
# [3200]	validation_0-error:0.149315
# [3201]	validation_0-error:0.149245
# [3202]	validation_0-error:0.149245
# [3203]	validation_0-error:0.149245
# [3204]	validation_0-error:0.149315
# [3205]	validation_0-error:0.149385
# [3206]	validation_0-error:0.14928
# [3207]	validation_0-error:0.149245
# [3208]	validation_0-error:0.149245
# [3209]	validation_0-error:0.14928
# [3210]	validation_0-error:0.149175
# [3211]	validation_0-error:0.149245
# [3212]	validation_0-error:0.149245
# [3213]	validation_0-error:0.14921
# [3214]	validation_0-error:0.14921
# [3215]	validation_0-error:0.14935
# [3216]	validation_0-error:0.149315
# [3217]	validation_0-error:0.14921
# [3218]	validation_0-error:0.149175
# [3219]	validation_0-error:0.149175
# [3220]	validation_0-error:0.149139
# [3221]	validation_0-error:0.149139
# [3222]	validation_0-error:0.149069
# [3223]	validation_0-error:0.149139
# [3224]	validation_0-error:0.149139
# [3225]	validation_0-error:0.149139
# [3226]	validation_0-error:0.149139
# [3227]	validation_0-error:0.149175
# [3228]	validation_0-error:0.149034
# [3229]	validation_0-error:0.149034
# [3230]	validation_0-error:0.148999
# [3231]	validation_0-error:0.148999
# [3232]	validation_0-error:0.149034
# [3233]	validation_0-error:0.148999
# [3234]	validation_0-error:0.148964
# [3235]	validation_0-error:0.148964
# [3236]	validation_0-error:0.148999
# [3237]	validation_0-error:0.148964
# [3238]	validation_0-error:0.148929
# [3239]	validation_0-error:0.148894
# [3240]	validation_0-error:0.148894
# [3241]	validation_0-error:0.148858
# [3242]	validation_0-error:0.148823
# [3243]	validation_0-error:0.148823
# [3244]	validation_0-error:0.148858
# [3245]	validation_0-error:0.148788
# [3246]	validation_0-error:0.148788
# [3247]	validation_0-error:0.148788
# [3248]	validation_0-error:0.148788
# [3249]	validation_0-error:0.148788
# [3250]	validation_0-error:0.148788
# [3251]	validation_0-error:0.148823
# [3252]	validation_0-error:0.148788
# [3253]	validation_0-error:0.148788
# [3254]	validation_0-error:0.148718
# [3255]	validation_0-error:0.148718
# [3256]	validation_0-error:0.148718
# [3257]	validation_0-error:0.148718
# [3258]	validation_0-error:0.148718
# [3259]	validation_0-error:0.148718
# [3260]	validation_0-error:0.148718
# [3261]	validation_0-error:0.148718
# [3262]	validation_0-error:0.148718
# [3263]	validation_0-error:0.148718
# [3264]	validation_0-error:0.148753
# [3265]	validation_0-error:0.148753
# [3266]	validation_0-error:0.148753
# [3267]	validation_0-error:0.148683
# [3268]	validation_0-error:0.148648
# [3269]	validation_0-error:0.148613
# [3270]	validation_0-error:0.148613
# [3271]	validation_0-error:0.148577
# [3272]	validation_0-error:0.148542
# [3273]	validation_0-error:0.148542
# [3274]	validation_0-error:0.148542
# [3275]	validation_0-error:0.148507
# [3276]	validation_0-error:0.148472
# [3277]	validation_0-error:0.148472
# [3278]	validation_0-error:0.148507
# [3279]	validation_0-error:0.148542
# [3280]	validation_0-error:0.148577
# [3281]	validation_0-error:0.148577
# [3282]	validation_0-error:0.148577
# [3283]	validation_0-error:0.148542
# [3284]	validation_0-error:0.148542
# [3285]	validation_0-error:0.148613
# [3286]	validation_0-error:0.148683
# [3287]	validation_0-error:0.148718
# [3288]	validation_0-error:0.148718
# [3289]	validation_0-error:0.148683
# [3290]	validation_0-error:0.148683
# [3291]	validation_0-error:0.148753
# [3292]	validation_0-error:0.148788
# [3293]	validation_0-error:0.148753
# [3294]	validation_0-error:0.148753
# [3295]	validation_0-error:0.148683
# [3296]	validation_0-error:0.148683
# [3297]	validation_0-error:0.148683
# [3298]	validation_0-error:0.148683
# [3299]	validation_0-error:0.148683
# [3300]	validation_0-error:0.148683
# [3301]	validation_0-error:0.148718
# [3302]	validation_0-error:0.148718
# [3303]	validation_0-error:0.148718
# [3304]	validation_0-error:0.148718
# [3305]	validation_0-error:0.148683
# [3306]	validation_0-error:0.148648
# [3307]	validation_0-error:0.148648
# [3308]	validation_0-error:0.148683
# [3309]	validation_0-error:0.148683
# [3310]	validation_0-error:0.148683
# [3311]	validation_0-error:0.148718
# [3312]	validation_0-error:0.148718
# [3313]	validation_0-error:0.148648
# [3314]	validation_0-error:0.148648
# [3315]	validation_0-error:0.148718
# [3316]	validation_0-error:0.148753
# [3317]	validation_0-error:0.148753
# [3318]	validation_0-error:0.148753
# [3319]	validation_0-error:0.148753
# [3320]	validation_0-error:0.148718
# [3321]	validation_0-error:0.148718
# [3322]	validation_0-error:0.148718
# [3323]	validation_0-error:0.148718
# [3324]	validation_0-error:0.148718
# [3325]	validation_0-error:0.148718
# [3326]	validation_0-error:0.148753
# [3327]	validation_0-error:0.148753
# [3328]	validation_0-error:0.148753
# [3329]	validation_0-error:0.148753
# [3330]	validation_0-error:0.148753
# [3331]	validation_0-error:0.148753
# [3332]	validation_0-error:0.148788
# [3333]	validation_0-error:0.148823
# [3334]	validation_0-error:0.148823
# [3335]	validation_0-error:0.148823
# [3336]	validation_0-error:0.148788
# [3337]	validation_0-error:0.148718
# [3338]	validation_0-error:0.148718
# [3339]	validation_0-error:0.148683
# [3340]	validation_0-error:0.148683
# [3341]	validation_0-error:0.148648
# [3342]	validation_0-error:0.148648
# [3343]	validation_0-error:0.148648
# [3344]	validation_0-error:0.148753
# [3345]	validation_0-error:0.148683
# [3346]	validation_0-error:0.148718
# [3347]	validation_0-error:0.148683
# [3348]	validation_0-error:0.148683
# [3349]	validation_0-error:0.148613
# [3350]	validation_0-error:0.148577
# [3351]	validation_0-error:0.148577
# [3352]	validation_0-error:0.148577
# [3353]	validation_0-error:0.148613
# [3354]	validation_0-error:0.148613
# [3355]	validation_0-error:0.148613
# [3356]	validation_0-error:0.148648
# [3357]	validation_0-error:0.148648
# [3358]	validation_0-error:0.148648
# [3359]	validation_0-error:0.148718
# [3360]	validation_0-error:0.148718
# [3361]	validation_0-error:0.148683
# [3362]	validation_0-error:0.148683
# [3363]	validation_0-error:0.148648
# [3364]	validation_0-error:0.148648
# [3365]	validation_0-error:0.148648
# [3366]	validation_0-error:0.148648
# [3367]	validation_0-error:0.148648
# [3368]	validation_0-error:0.148542
# [3369]	validation_0-error:0.148542
# [3370]	validation_0-error:0.148613
# [3371]	validation_0-error:0.148613
# [3372]	validation_0-error:0.148613
# [3373]	validation_0-error:0.148613
# [3374]	validation_0-error:0.148613
# [3375]	validation_0-error:0.148613
# [3376]	validation_0-error:0.148542
# Stopping. Best iteration:
# [3276]	validation_0-error:0.148472

# %%
np.mean(ws100_preds == y_test), f1_score(y_test, ws100_preds, average='macro')
# Out:
# (0.8494922163263872, 0.8493958059382059)

# %%
result['xgboost-pred'] = ws100_preds

# %% [markdown]
# ### **Decision Tree**

# %%
dt_wrapper = DecisionTreeClassifier(
                            criterion = 'entropy',
                            max_depth = 500,
                            random_state = 42
                            )
dt_wrapper.fit(x_dev_tfidf, y_dev)
dt_preds = dt_wrapper.predict(x_dev_test_tfidf)

# %%
np.mean(dt_preds == y_test), f1_score(y_test, dt_preds, average=None)
# Out:
# (0.7901746494711319, array([0.80741816, 0.76953954]))

# %%
test_model(dt_wrapper, input='좆까')
# Out:
# array([0])

# %%
result['dt-pred'] = dt_preds

# %% [markdown]
# ### **Support Vector Classifier**

# %%
svc_clf = SVC(
            C = 50, 
            kernel = 'rbf',
            gamma = 1
            )

# %%
svc_clf.fit(x_dev_tfidf, y_dev)
# Out:
# SVC(C=50, gamma=1)

# %%
svc_preds = svc_clf.predict(x_dev_test_tfidf)
np.mean(svc_preds == y_test), f1_score(y_test, svc_preds, average='macro')
# Out:
# (0.8909231472045542, 0.890231424128916)

# %%
test_model(svc_clf, input='많이 까다롭구나...')
# Out:
# array([1])

# %%
result['svc-pred'] = svc_preds

# %%
save_model(model=svc_clf, filename='svc-model.pkl')
# clf_from_joblib = joblib.load('svc-model.pkl')
# Out:
# svc-model.pkl

# %% [markdown]
# ### **KNeighbors**

# %%
kn_clf = KNeighborsClassifier(
                        n_neighbors=300, 
                        algorithm='ball_tree',
                        leaf_size=2,
                        n_jobs=-1)

kn_clf.fit(x_dev_tfidf, y_dev)
kn_preds = kn_clf.predict(x_dev_test_tfidf)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_base.py:504: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: using brute force")

# %%
np.mean(kn_preds == y_test), f1_score(y_test, kn_preds, average='macro')
# Out:
# (0.5363882348806972, 0.3692710034992872)

# %%
result['kn-pred'] = kn_preds

# %% [markdown]
# ### **Export Result**

# %%
result.to_csv('ml-result.csv', index=False)
